# %% [markdown]
# # Importing Dataset

# %% [markdown]
# # Project Overview: Laptop Price Prediction
#
# This project aims to build a machine learning model to predict the price of laptops based on their specifications. The process involves several key steps:
#
# 1.  **Data Loading and Initial Analysis:** The dataset containing various laptop specifications and their prices is loaded into a pandas DataFrame. Initial checks are performed to understand the data structure, identify missing values, and check for duplicates.
#
# 2.  **Data Cleaning and Preprocessing:** The dataset is cleaned by dropping irrelevant columns and handling missing values in the 'Storage' column by filling them with the most frequent value. Categorical features like 'Processor' and 'Operating System' are standardized by grouping similar categories. Numerical features like 'Storage', 'RAM', and 'Screen Size' are cleaned by removing units and converting them to appropriate data types. The 'Price' column is also cleaned and converted to an integer type. Finally, columns are renamed for better readability.
#
# 3.  **Feature Engineering and Encoding:** The 'Processor' and 'Operating System' columns are one-hot encoded to convert them into a numerical format suitable for machine learning models. The 'Touch Screen' column is mapped to numerical values (0 for No, 1 for Yes).
#
# 4.  **Model Selection and Training:** The data is split into training and testing sets. Two linear regression models, Linear Regression and Lasso Regression, are chosen for predicting the laptop prices. A pipeline is created to chain the preprocessing steps (one-hot encoding) and the regression model. The models are then trained on the training data.
#
# 5.  **Model Evaluation and Prediction:** The trained models are evaluated on the testing data using the R2 score to assess their performance. Predictions are made on sample real-world data to demonstrate the models' ability to predict laptop prices.
#
# This project demonstrates a typical machine learning workflow, from data cleaning and preprocessing to model training and evaluation, for a regression task.

# %%
import pandas as pd

# %%
df = pd.read_csv(r'D:\My Drive\Laptops.csv')
df
# Out:
#      Unnamed: 0    Brand               Model Name          Processor  \
# 0             0       HP             15s-fq5007TU            Core i3
# 1             1       HP             15s-fy5003TU            Core i3
# 2             2    Apple         2020 Macbook Air                 M1
# 3             3    Apple         2020 Macbook Air                 M1
# 4             4    Apple         2020 Macbook Air                 M1
# ..          ...      ...                      ...                ...
# 832         832       HP                   255 G8  Ryzen 5 Hexa Core
# 833         833     DELL            Inspiron 7430            Core i3
# 834         834      MSI  Katana 17 B13UCXK-256IN            Core i7
# 835         835  Infinix                     XL25            Core i5
# 836         836       HP              13-BE0030AU  Ryzen 5 Hexa Core
#
#     Operating System Storage    RAM           Screen Size Touch_Screen  \
# 0    Windows 11 Home  512 GB   8 GB  39.62 cm (15.6 Inch)           No
# 1    Windows 11 Home  512 GB   8 GB  39.62 cm (15.6 Inch)           No
# 2     Mac OS Big Sur  256 GB   8 GB  33.78 cm (13.3 inch)           No
# 3     Mac OS Big Sur  256 GB   8 GB  33.78 cm (13.3 inch)           No
# 4     Mac OS Big Sur  256 GB   8 GB  33.78 cm (13.3 inch)           No
# ..               ...     ...    ...                   ...          ...
# 832  Windows 11 Home  512 GB   8 GB  39.62 cm (15.6 inch)           No
# 833  Windows 11 Home    1 TB   8 GB    35.56 cm (14 inch)          Yes
# 834  Windows 11 Home    4 TB  16 GB  43.94 cm (17.3 Inch)           No
# 835  Windows 11 Home  512 GB   8 GB  39.62 cm (15.6 Inch)           No
# 836  Windows 10 Home  512 GB  16 GB  33.78 cm (13.3 inch)           No
#
#        Price
# 0    ₹38,990
# 1    ₹37,990
# 2    ₹70,990
# 3    ₹70,990
# 4    ₹70,990
# ..       ...
# 832  ₹42,990
# 833  ₹60,490
# 834  ₹88,990
# 835  ₹37,990
# 836  ₹70,500
#
# [837 rows x 10 columns]

# %% [markdown]
# # Data Analysis

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 837 entries, 0 to 836
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        837 non-null    int64
#  1   Brand             837 non-null    object
#  2   Model Name        837 non-null    object
#  3   Processor         837 non-null    object
#  4   Operating System  837 non-null    object
#  5   Storage           825 non-null    object
#  6   RAM               837 non-null    object
#  7   Screen Size       837 non-null    object
#  8   Touch_Screen      837 non-null    object
#  9   Price             837 non-null    object
# dtypes: int64(1), object(9)
# memory usage: 65.5+ KB

# %%
df.isnull().sum()
# Out:
# Unnamed: 0           0
# Brand                0
# Model Name           0
# Processor            0
# Operating System     0
# Storage             12
# RAM                  0
# Screen Size          0
# Touch_Screen         0
# Price                0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# # Data Cleaning

# %%
df.drop(columns=['Unnamed: 0'], inplace=True)
df
# Out:
#        Brand               Model Name          Processor Operating System  \
# 0         HP             15s-fq5007TU            Core i3  Windows 11 Home
# 1         HP             15s-fy5003TU            Core i3  Windows 11 Home
# 2      Apple         2020 Macbook Air                 M1   Mac OS Big Sur
# 3      Apple         2020 Macbook Air                 M1   Mac OS Big Sur
# 4      Apple         2020 Macbook Air                 M1   Mac OS Big Sur
# ..       ...                      ...                ...              ...
# 832       HP                   255 G8  Ryzen 5 Hexa Core  Windows 11 Home
# 833     DELL            Inspiron 7430            Core i3  Windows 11 Home
# 834      MSI  Katana 17 B13UCXK-256IN            Core i7  Windows 11 Home
# 835  Infinix                     XL25            Core i5  Windows 11 Home
# 836       HP              13-BE0030AU  Ryzen 5 Hexa Core  Windows 10 Home
#
#     Storage    RAM           Screen Size Touch_Screen    Price
# 0    512 GB   8 GB  39.62 cm (15.6 Inch)           No  ₹38,990
# 1    512 GB   8 GB  39.62 cm (15.6 Inch)           No  ₹37,990
# 2    256 GB   8 GB  33.78 cm (13.3 inch)           No  ₹70,990
# 3    256 GB   8 GB  33.78 cm (13.3 inch)           No  ₹70,990
# 4    256 GB   8 GB  33.78 cm (13.3 inch)           No  ₹70,990
# ..      ...    ...                   ...          ...      ...
# 832  512 GB   8 GB  39.62 cm (15.6 inch)           No  ₹42,990
# 833    1 TB   8 GB    35.56 cm (14 inch)          Yes  ₹60,490
# 834    4 TB  16 GB  43.94 cm (17.3 Inch)           No  ₹88,990
# 835  512 GB   8 GB  39.62 cm (15.6 Inch)           No  ₹37,990
# 836  512 GB  16 GB  33.78 cm (13.3 inch)           No  ₹70,500
#
# [837 rows x 9 columns]

# %%
df['Storage'].value_counts()
# Out:
# 512 GB    627
# 1 TB      101
# 256 GB     49
# 2 TB       20
# 128 GB     12
# 4 TB       10
# 64 GB       4
# 3 TB        1
# 6 TB        1
# Name: Storage, dtype: int64

# %%
df['Storage'] = df['Storage'].fillna('512 GB')

# %%
df.isnull().sum()
# Out:
# Brand               0
# Model Name          0
# Processor           0
# Operating System    0
# Storage             0
# RAM                 0
# Screen Size         0
# Touch_Screen        0
# Price               0
# dtype: int64

# %%
for column in df.columns:
    print(df[column].value_counts())
    print('-'*50)
# Out:
# HP           423
# ASUS         147
# Lenovo        62
# DELL          59
# Acer          36
# MSI           32
# Infinix       29
# Apple         11
# SAMSUNG        9
# CHUWI          7
# GIGABYTE       5
# WINGS          4
# ZEBRONICS      4
# MICROSOFT      3
# Ultimus        2
# LG             2
# realme         1
# Primebook      1
# Name: Brand, dtype: int64
# --------------------------------------------------
# 15s- fr5011TU           37
# 15s-fy5003TU            37
# 15s- fr4000TU           37
# 15s-fq5007TU            36
# 15s-fy5002TU            34
#                         ..
# Vivobook 15 X1504ZA      1
# Thin GF63 12VE-664IN     1
# 15-eg2017TU              1
# K3605ZC-MBN542WS         1
# 13-BE0030AU              1
# Name: Model Name, Length: 377, dtype: int64
# --------------------------------------------------
# Core i5                   365
# Core i3                   163
# Ryzen 5 Hexa Core          82
# Core i7                    68
# Ryzen 7 Octa Core          67
# Celeron Dual Core          16
# Ryzen 3 Quad Core          14
# Celeron Quad Core          10
# Ryzen 5 Quad Core          10
# Ryzen 3 Dual Core           7
# Athlon Dual Core            4
# Core i9                     4
# Pentium Silver              4
# M2                          3
# M1                          3
# Ryzen 9 Octa Core           2
# Ryzen 5                     2
# M1 Max                      1
# Ryzen 5 Dual Core           1
# Ryzen 7 Quad Core           1
# M1 Pro                      1
# M3 Pro                      1
# M2 Max                      1
# MediaTek MT8788             1
# Ryzen Z1 Octa Core          1
# MediaTek Kompanio 520       1
# MediaTek Kompanio 500       1
# Ryzen Z1 HexaCore           1
# MediaTek Kompanio 1200      1
# Ryzen 9 16 Core             1
# Name: Processor, dtype: int64
# --------------------------------------------------
# Windows 11 Home    758
# Windows 10 Home     27
# Chrome              13
# Windows 10          10
# DOS                  8
# Mac OS Monterey      5
# Windows 11 Pro       5
# Mac OS Big Sur       3
# Windows 10 Pro       3
# Prime OS             1
# Ubuntu               1
# macOS Ventura        1
# macOS Sonoma         1
# Mac OS Mojave        1
# Name: Operating System, dtype: int64
# --------------------------------------------------
# 512 GB    639
# 1 TB      101
# 256 GB     49
# 2 TB       20
# 128 GB     12
# 4 TB       10
# 64 GB       4
# 3 TB        1
# 6 TB        1
# Name: Storage, dtype: int64
# --------------------------------------------------
# 8 GB     421
# 16 GB    377
# 4 GB      25
# 32 GB      9
# 12 GB      2
# 64 GB      2
# 18 GB      1
# Name: RAM, dtype: int64
# --------------------------------------------------
# 39.62 cm (15.6 Inch)     368
# 39.62 cm (15.6 inch)     187
# 35.56 cm (14 inch)       124
# 35.56 cm (14 Inch)        53
# 40.64 cm (16 Inch)        19
# 33.78 cm (13.3 inch)      10
# 40.64 cm (16 inch)         8
# 40.89 cm (16.1 Inch)       7
# 43.94 cm (17.3 Inch)       6
# 33.78 cm (13.3 Inch)       6
# 96.52 cm (38 cm)           6
# 38.1 cm (15 inch)          4
# 35.81 cm (14.1 inch)       3
# 40.89 cm (16.1 inch)       3
# 39.01 cm (15.36 inch)      3
# 34.29 cm (13.5 inch)       3
# 35.81 cm (14.1 Inch)       2
# 33.02 cm (13 inch)         2
# 100.63 cm (39.62 cm)       2
# 17.78 cm (7 Inch)          2
# 43.94 cm (17.3 inch)       2
# 34.29 cm (13.5 Inch)       2
# 38.86 cm (15.3 Inch)       1
# 31.5 cm (12.4 Inch)        1
# 36.07 cm (14.2 inch)       1
# 38.0 cm (14.96 cm)         1
# 90.32 cm (35.56 cm)        1
# 30.48 cm (12 inch)         1
# 29.46 cm (11.6 Inch)       1
# 41.15 cm (16.2 inch)       1
# 34.04 cm (13.4 inch)       1
# 35.0 cm (13.78 inch)       1
# 34.04 cm (13.4 Inch)       1
# 26.67 cm (10.5 inch)       1
# 38.0 cm (14.96 Inch)       1
# 34.54 cm (13.6 Inch)       1
# 29.46 cm (11.6 inch)       1
# Name: Screen Size, dtype: int64
# --------------------------------------------------
# No     740
# Yes     97
# Name: Touch_Screen, dtype: int64
# --------------------------------------------------
# ₹53,990      65
# ₹37,990      42
# ₹54,990      41
# ₹49,990      40
# ₹38,990      39
#              ..
# ₹52,890       1
# ₹1,47,743     1
# ₹64,600       1
# ₹1,99,990     1
# ₹70,500       1
# Name: Price, Length: 270, dtype: int64
# --------------------------------------------------

# %%
df["Processor"] = df['Processor'].apply(lambda x:" ".join(x.split()[0:2]))

# %%
df['Processor'].value_counts()
# Out:
# Core i5              365
# Core i3              163
# Ryzen 5               95
# Core i7               68
# Ryzen 7               68
# Ryzen 3               21
# Celeron Dual          16
# Celeron Quad          10
# Core i9                4
# Pentium Silver         4
# Athlon Dual            4
# MediaTek Kompanio      3
# Ryzen 9                3
# M1                     3
# M2                     3
# Ryzen Z1               2
# MediaTek MT8788        1
# M1 Max                 1
# M2 Max                 1
# M3 Pro                 1
# M1 Pro                 1
# Name: Processor, dtype: int64

# %%
def processor_manufactuer(df):
    if 'core' in df.lower():
        return 'Intel'
    elif 'ryzen' in df.lower():
        return 'Amd'
    elif any (m in df for m in ["M1", "M2", "M3"]):
        return 'Mac'
    else:
        return 'Others'

# %%
df['Processor'] = df['Processor'].apply(processor_manufactuer)

# %%
df['Processor'].value_counts()
# Out:
# Intel     600
# Amd       189
# Others     38
# Mac        10
# Name: Processor, dtype: int64

# %%
def operationsystem(df):
    if 'windows' in df.lower():
        return 'Windows OS'
    elif 'mac' in df.lower():
        return 'Mac OS'
    elif 'chrome' in  df.lower():
        return 'Chrome OS'
    else:
        return 'Others'

# %%
df['Operating System']=df['Operating System'].apply(operationsystem)

# %%
df['Operating System'].value_counts()
# Out:
# Windows OS    803
# Chrome OS      13
# Mac OS         11
# Others         10
# Name: Operating System, dtype: int64

# %%
df['Storage']=df['Storage'].str.replace('GB','')
df['Storage']=df['Storage'].str.replace('TB','000')
df['Storage']=df['Storage'].str.replace(' ','')
df['Storage']=df['Storage'].astype(int)

# %%
df['Storage'].value_counts()
# Out:
# 512     639
# 1000    101
# 256      49
# 2000     20
# 128      12
# 4000     10
# 64        4
# 3000      1
# 6000      1
# Name: Storage, dtype: int64

# %%
df['RAM']=df['RAM'].str.replace('GB','')
df['RAM']=df['RAM'].astype(int)

# %%
df['RAM'].value_counts()
# Out:
# 8     421
# 16    377
# 4      25
# 32      9
# 12      2
# 64      2
# 18      1
# Name: RAM, dtype: int64

# %%
df['Screen Size'] = df['Screen Size'].apply(lambda x:''.join(x.split(' ')[0]))
df['Screen Size']= df['Screen Size'].astype(float)

# %%
df['Screen Size'].value_counts()
# Out:
# 39.62     555
# 35.56     177
# 40.64      27
# 33.78      16
# 40.89      10
# 43.94       8
# 96.52       6
# 35.81       5
# 34.29       5
# 38.10       4
# 39.01       3
# 17.78       2
# 33.02       2
# 34.04       2
# 29.46       2
# 38.00       2
# 100.63      2
# 26.67       1
# 34.54       1
# 35.00       1
# 41.15       1
# 90.32       1
# 30.48       1
# 38.86       1
# 36.07       1
# 31.50       1
# Name: Screen Size, dtype: int64

# %%
df['Price']=df['Price'].str.replace('₹','')
df['Price']=df['Price'].str.replace(',','')
df['Price']=df['Price'].astype(int)

# %%
df['Price'].value_counts()
# Out:
# 53990     65
# 37990     42
# 54990     41
# 49990     40
# 38990     39
#           ..
# 52890      1
# 147743     1
# 64600      1
# 199990     1
# 70500      1
# Name: Price, Length: 270, dtype: int64

# %%
df.rename(columns={'Storage':'Storage(GB)','RAM':'RAM(GB)','Screen Size':'Screen Size(CM)','Touch_Screen':'Touch Screen','Price':'Price(₹)'},inplace=True)

# %% [markdown]
# # Cleaned Dataset

# %%
df
# Out:
#        Brand               Model Name Processor Operating System  Storage(GB)  \
# 0         HP             15s-fq5007TU     Intel       Windows OS          512
# 1         HP             15s-fy5003TU     Intel       Windows OS          512
# 2      Apple         2020 Macbook Air       Mac           Mac OS          256
# 3      Apple         2020 Macbook Air       Mac           Mac OS          256
# 4      Apple         2020 Macbook Air       Mac           Mac OS          256
# ..       ...                      ...       ...              ...          ...
# 832       HP                   255 G8       Amd       Windows OS          512
# 833     DELL            Inspiron 7430     Intel       Windows OS         1000
# 834      MSI  Katana 17 B13UCXK-256IN     Intel       Windows OS         4000
# 835  Infinix                     XL25     Intel       Windows OS          512
# 836       HP              13-BE0030AU       Amd       Windows OS          512
#
#      RAM(GB)  Screen Size(CM) Touch Screen  Price(₹)
# 0          8            39.62           No     38990
# 1          8            39.62           No     37990
# 2          8            33.78           No     70990
# 3          8            33.78           No     70990
# 4          8            33.78           No     70990
# ..       ...              ...          ...       ...
# 832        8            39.62           No     42990
# 833        8            35.56          Yes     60490
# 834       16            43.94           No     88990
# 835        8            39.62           No     37990
# 836       16            33.78           No     70500
#
# [837 rows x 9 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 837 entries, 0 to 836
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Brand             837 non-null    object
#  1   Model Name        837 non-null    object
#  2   Processor         837 non-null    object
#  3   Operating System  837 non-null    object
#  4   Storage(GB)       837 non-null    int32
#  5   RAM(GB)           837 non-null    int32
#  6   Screen Size(CM)   837 non-null    float64
#  7   Touch Screen      837 non-null    object
#  8   Price(₹)          837 non-null    int32
# dtypes: float64(1), int32(3), object(5)
# memory usage: 49.2+ KB

# %%
df.describe()
# Out:
#        Storage(GB)     RAM(GB)  Screen Size(CM)       Price(₹)
# count   837.000000  837.000000       837.000000     837.000000
# mean    635.010753   11.897252        39.128913   59919.016726
# std     512.316622    5.290956         6.453314   37594.119774
# min      64.000000    4.000000        17.780000   11990.000000
# 25%     512.000000    8.000000        35.560000   38990.000000
# 50%     512.000000    8.000000        39.620000   53990.000000
# 75%     512.000000   16.000000        39.620000   66999.000000
# max    6000.000000   64.000000       100.630000  489990.000000

# %% [markdown]
# # Data Preprocessing

# %%
df = pd.get_dummies(df,columns=['Processor','Operating System'])
df
# Out:
#        Brand               Model Name  Storage(GB)  RAM(GB)  Screen Size(CM)  \
# 0         HP             15s-fq5007TU          512        8            39.62
# 1         HP             15s-fy5003TU          512        8            39.62
# 2      Apple         2020 Macbook Air          256        8            33.78
# 3      Apple         2020 Macbook Air          256        8            33.78
# 4      Apple         2020 Macbook Air          256        8            33.78
# ..       ...                      ...          ...      ...              ...
# 832       HP                   255 G8          512        8            39.62
# 833     DELL            Inspiron 7430         1000        8            35.56
# 834      MSI  Katana 17 B13UCXK-256IN         4000       16            43.94
# 835  Infinix                     XL25          512        8            39.62
# 836       HP              13-BE0030AU          512       16            33.78
#
#     Touch Screen  Price(₹)  Processor_Amd  Processor_Intel  Processor_Mac  \
# 0             No     38990              0                1              0
# 1             No     37990              0                1              0
# 2             No     70990              0                0              1
# 3             No     70990              0                0              1
# 4             No     70990              0                0              1
# ..           ...       ...            ...              ...            ...
# 832           No     42990              1                0              0
# 833          Yes     60490              0                1              0
# 834           No     88990              0                1              0
# 835           No     37990              0                1              0
# 836           No     70500              1                0              0
#
#      Processor_Others  Operating System_Chrome OS  Operating System_Mac OS  \
# 0                   0                           0                        0
# 1                   0                           0                        0
# 2                   0                           0                        1
# 3                   0                           0                        1
# 4                   0                           0                        1
# ..                ...                         ...                      ...
# 832                 0                           0                        0
# 833                 0                           0                        0
# 834                 0                           0                        0
# 835                 0                           0                        0
# 836                 0                           0                        0
#
#      Operating System_Others  Operating System_Windows OS
# 0                          0                            1
# 1                          0                            1
# 2                          0                            0
# 3                          0                            0
# 4                          0                            0
# ..                       ...                          ...
# 832                        0                            1
# 833                        0                            1
# 834                        0                            1
# 835                        0                            1
# 836                        0                            1
#
# [837 rows x 15 columns]

# %%
df['Touch Screen'] = df['Touch Screen'].map({'Yes':1,'No':0})
df
# Out:
#        Brand               Model Name  Storage(GB)  RAM(GB)  Screen Size(CM)  \
# 0         HP             15s-fq5007TU          512        8            39.62
# 1         HP             15s-fy5003TU          512        8            39.62
# 2      Apple         2020 Macbook Air          256        8            33.78
# 3      Apple         2020 Macbook Air          256        8            33.78
# 4      Apple         2020 Macbook Air          256        8            33.78
# ..       ...                      ...          ...      ...              ...
# 832       HP                   255 G8          512        8            39.62
# 833     DELL            Inspiron 7430         1000        8            35.56
# 834      MSI  Katana 17 B13UCXK-256IN         4000       16            43.94
# 835  Infinix                     XL25          512        8            39.62
# 836       HP              13-BE0030AU          512       16            33.78
#
#      Touch Screen  Price(₹)  Processor_Amd  Processor_Intel  Processor_Mac  \
# 0               0     38990              0                1              0
# 1               0     37990              0                1              0
# 2               0     70990              0                0              1
# 3               0     70990              0                0              1
# 4               0     70990              0                0              1
# ..            ...       ...            ...              ...            ...
# 832             0     42990              1                0              0
# 833             1     60490              0                1              0
# 834             0     88990              0                1              0
# 835             0     37990              0                1              0
# 836             0     70500              1                0              0
#
#      Processor_Others  Operating System_Chrome OS  Operating System_Mac OS  \
# 0                   0                           0                        0
# 1                   0                           0                        0
# 2                   0                           0                        1
# 3                   0                           0                        1
# 4                   0                           0                        1
# ..                ...                         ...                      ...
# 832                 0                           0                        0
# 833                 0                           0                        0
# 834                 0                           0                        0
# 835                 0                           0                        0
# 836                 0                           0                        0
#
#      Operating System_Others  Operating System_Windows OS
# 0                          0                            1
# 1                          0                            1
# 2                          0                            0
# 3                          0                            0
# 4                          0                            0
# ..                       ...                          ...
# 832                        0                            1
# 833                        0                            1
# 834                        0                            1
# 835                        0                            1
# 836                        0                            1
#
# [837 rows x 15 columns]

# %% [markdown]
# # Defining X & y for Training and Testing Dataset

# %%
X = df.drop(columns='Price(₹)')
X
# Out:
#        Brand               Model Name  Storage(GB)  RAM(GB)  Screen Size(CM)  \
# 0         HP             15s-fq5007TU          512        8            39.62
# 1         HP             15s-fy5003TU          512        8            39.62
# 2      Apple         2020 Macbook Air          256        8            33.78
# 3      Apple         2020 Macbook Air          256        8            33.78
# 4      Apple         2020 Macbook Air          256        8            33.78
# ..       ...                      ...          ...      ...              ...
# 832       HP                   255 G8          512        8            39.62
# 833     DELL            Inspiron 7430         1000        8            35.56
# 834      MSI  Katana 17 B13UCXK-256IN         4000       16            43.94
# 835  Infinix                     XL25          512        8            39.62
# 836       HP              13-BE0030AU          512       16            33.78
#
#      Touch Screen  Processor_Amd  Processor_Intel  Processor_Mac  \
# 0               0              0                1              0
# 1               0              0                1              0
# 2               0              0                0              1
# 3               0              0                0              1
# 4               0              0                0              1
# ..            ...            ...              ...            ...
# 832             0              1                0              0
# 833             1              0                1              0
# 834             0              0                1              0
# 835             0              0                1              0
# 836             0              1                0              0
#
#      Processor_Others  Operating System_Chrome OS  Operating System_Mac OS  \
# 0                   0                           0                        0
# 1                   0                           0                        0
# 2                   0                           0                        1
# 3                   0                           0                        1
# 4                   0                           0                        1
# ..                ...                         ...                      ...
# 832                 0                           0                        0
# 833                 0                           0                        0
# 834                 0                           0                        0
# 835                 0                           0                        0
# 836                 0                           0                        0
#
#      Operating System_Others  Operating System_Windows OS
# 0                          0                            1
# 1                          0                            1
# 2                          0                            0
# 3                          0                            0
# 4                          0                            0
# ..                       ...                          ...
# 832                        0                            1
# 833                        0                            1
# 834                        0                            1
# 835                        0                            1
# 836                        0                            1
#
# [837 rows x 14 columns]

# %%
y = df[['Price(₹)']]
y
# Out:
#      Price(₹)
# 0       38990
# 1       37990
# 2       70990
# 3       70990
# 4       70990
# ..        ...
# 832     42990
# 833     60490
# 834     88990
# 835     37990
# 836     70500
#
# [837 rows x 1 columns]

# %% [markdown]
# # Split Dataset into Training & Testing

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2,random_state=0)

# %% [markdown]
# # Make Column Transformer

# %%
from sklearn.compose import make_column_transformer
from sklearn.preprocessing import OneHotEncoder

# %%
ohe = OneHotEncoder()
ohe.fit(X[['Brand','Model Name']])
# Out:
# OneHotEncoder()

# %%
ohe.categories_
# Out:
# [array(['ASUS', 'Acer', 'Apple', 'CHUWI', 'DELL', 'GIGABYTE', 'HP',
#         'Infinix', 'LG', 'Lenovo', 'MICROSOFT', 'MSI', 'Primebook',
#         'SAMSUNG', 'Ultimus', 'WINGS', 'ZEBRONICS', 'realme'], dtype=object),
#  array(['11IGL05', '13-BE0030AU', '13ABR8', '13b-ca0006MU', '14-EC1019AU',
#         '14-dv1000TU', '14-dv1029TU', '14-dv2014TU', '14-dv2053TU',
#         '14-dv2153TU', '14-dy1013TU', '14-ec0033AU', '14-eh0024TU',
#         '14IAU7', '14ITL6', '14M868', '14a-ca0504TU', '14c-cc0010TU',
#         '14s', '14s - dy2507TU', '14s - dy2508TU', '14s- dy2506TU',
#         '14s-dq2606tu', '14s-ef1001tu', '14s-ef1002tu', '14s-fy1003AU',
#         '14s-fy1005AU', '15', '15-EG2009TU', '15-eg2017TU', '15-eg2091T',
#         '15-eg3079TU', '15-fa0070TX', '15-fa0188TX', '15-fa0354TX',
#         '15-fa1060TX', '15-fb0106AX', '15-fb0131AX', '15-fb0135AX',
#         '15-fb0137AX', '15-fb0147AX', '15-fb0150AX', '15-fb1016AX',
#         '15-fc0031AU', '15-fd0011TU', '15-fd0012TU', '15-fd0019TU',
#         '15-fd0022TU', '15-fd0024TU', '15-fe0027TU', '15-fh0015AU',
#         '15ACH6', '15ACH6H', '15AMN7', '15APH8', '15ARH7', '15IAH7',
#         '15IAU7', '15IGL05', '15IHU6', '15IRH8', '15IRU8', '15ITL05',
#         '15ITL6', '15S-FQ2738TU', '15a- na0012TU', '15s', '15s FR2508TU',
#         '15s- eq1580AU', '15s- eq2144au', '15s- eq2212AU', '15s- eq2213AU',
#         '15s- eq2223AU', '15s- ey2001au', '15s- fq3066TU', '15s- fr4000TU',
#         '15s- fr5011TU', '15s-du3517TU', '15s-dy3501TU', '15s-eq2132au',
#         '15s-ey1509AU', '15s-fq2627TU', '15s-fq2717TU', '15s-fq5007TU',
#         '15s-fq5013nia', '15s-fq5112TU', '15s-fq5202TU', '15s-fr4001TU',
#         '15s-fy5002TU', '15s-fy5003TU', '15s-fy5006TU', '15s-fy5007TU',
#         '16-d0333TX', '16-e0162AX', '16-n0050AX', '16-wd0880TX', '16ACH6H',
#         '16APH8', '16ARH7H', '16IAH8', '2020 Macbook Air', '245 G',
#         '245 G8', '247 G8', '250 G8', '255 G8', '255 G8 Laptop',
#         'A315-24P', 'A315-510P', 'A315-59', 'A514-56GM', 'A515-56',
#         'A515-56G', 'A715-51G', 'A715-76G', 'AN515-45', 'AN515-47',
#         'AN515-57', 'AN515-58', 'ANV15-51', 'AORUS 15 BKF',
#         'Alienware x17 R2', 'Aspire 3', 'Aspire 5', 'Aspire 5 Gaming',
#         'Aspire 7', 'Aspire Lite', 'B9450FA-BM0696R', 'Book Prime',
#         'Bravo 15 B5ED', 'Bravo 15 B7ED-011IN', 'CB314-3H',
#         'CM3000DVA-HT0038', 'CX1400FKA-EC0158', 'CX1500CKA-EJ0277',
#         'Chromebook', 'CoreBook X', 'CreatorPro M16 A12UIS',
#         'E1404FA-NK321WS', 'E1404FA-NK322WS', 'E1404GA-NK322WS',
#         'E1504FA-LK321WS', 'E1504FA-LK323WS', 'E1504FA-LK521WS',
#         'E1504FA-NJ322WS', 'E41-55', 'E510MA-EJ001W', 'E510MA-EJ011WS',
#         'E510MA-EJ021WS', 'EG2002TU', 'EX215-23', 'EX215-54', 'Envy',
#         'FA577NU-LP082W', 'FX506HCB-HN228T', 'FX506HF-HN026W',
#         'FX506LHB-HN355W | FX506LH-HN258W', 'FX507VU-LP083WS',
#         'FX507ZC4-HN116W', 'FX507ZC4-HN116WS', 'FX517ZE-HN035WS',
#         'FX707ZC4-HX048WS', 'FreeBook', 'G15', 'G15-5510', 'G15-5520',
#         'G15-5525', 'G5 GE-51IN263SH', 'G5 MF-E2IN313SH', 'G513RC-HN061W',
#         'G513RC-HN083W', 'G533ZXZ-LN116WS', 'G614JU-N3221WS',
#         'GA401QE-K2166TS', 'GF63 Thin 11SC-1493IN',
#         'GF63 Thin 11UC-1294IN', 'GF63 Thin 11UCX-1471IN',
#         'GF63 Thin 11UCX-1496IN', 'GX650PZ-NM047WS', 'GX650RXZ-LS228WS',
#         'GZ301ZE-LC193WS', 'Galaxy Book2 Pro', 'Galaxy Book3',
#         'Galaxy Book3 360', 'Galaxy Book3 Pro', 'Galaxy Book3 Pro 360',
#         'Gaming 5530', 'Gaming F15', 'GemiBook X Pro',
#         'HP 240 G8 (689U2PA)', 'HP Pavilion 15', 'Hero Book Pro',
#         'INBook X1', 'INBook X1 Neo', 'INBook X2 Plus Core i7',
#         'INBook Y1 Plus', 'INBook Y2 Plus', 'INSP 5620', 'IdeaPad Slim 3i',
#         'IdeaPad Slim 5i', 'Ideapad 3', 'Ideapad 5 14ABR8', 'Inbook',
#         'Inspiron', 'Inspiron 13 7000', 'Inspiron 15 3511',
#         'Inspiron 3501', 'Inspiron 3505', 'Inspiron 3511', 'Inspiron 3520',
#         'Inspiron 3521', 'Inspiron 3530', 'Inspiron 3535', 'Inspiron 5410',
#         'Inspiron 5430', 'Inspiron 5518', 'Inspiron 7430', 'Intel',
#         'K3405VCB-KM541WS', 'K3405VFB-KM541WS', 'K3405ZF-LY542WS',
#         'K3504VAB-NJ322WS', 'K3504VAB-NJ541WS', 'K3605ZC-MBN541WS',
#         'K3605ZC-MBN542WS', 'K3605ZC-MBN752WS', 'K3605ZU-MBN541WS',
#         'K513EA-L302WS', 'K513EA-L312WS', 'KM513UA-L512WS',
#         'KM513UA-L713WS', 'Katana 15 B12UDXK-1006IN',
#         'Katana 15 B12VFK-299IN', 'Katana 17 B13UCXK-256IN',
#         'Katana 17 B13UDXK-255IN', 'Katana 17 B13VEK-254IN',
#         'Katana GF66 12UC-881IN', 'LG Gram 14Z90Q-G.AJ56A2', 'Latitude 14',
#         'Latitude 3420', 'Lenovo V15', 'M1502QA-EJ741WS',
#         'M1603QA-MB511WS', 'M1605YA-MB551WS', 'M6500QC', 'M6500QC-HN542WS',
#         'M6500QF-HN521W', 'M6500QFB-LK741WS', 'M6500QFB-LK742WS',
#         'MK1A3HN/A', 'MKGT3HN/A', 'MPHG3HN/A', 'MacBook Air',
#         'MacBook Pro', 'Modern 14 C11M-030IN', 'Modern 14 C11M-031IN',
#         'Modern 14 C12M-670IN', 'Modern 14 C13M-435IN',
#         'Modern 14 C13M-438IN', 'Modern 14 C7M-062IN',
#         'Modern 14 C7M-063IN', 'NP550', 'NU14U3INC43BN-MB',
#         'NU14U3INF56BN-SG', 'Natural Silver', 'New Inspiron 15 Laptop',
#         'Nitro', 'Notebook', 'Omen', 'PHN16-71', 'Pavilion',
#         'Pavilion 15-EH3101AU', 'Pavilion x360', 'Pavilion x360 2-in-1',
#         'Primebook S 4G', 'Pro 15 OLED', 'QEZ-00048', 'QEZ-00065',
#         'RC45KD', 'RC71L-NH001W', 'RC71L-NH019W', 'ROG Strix G15',
#         'Raider GE66 12UGS', 'Raider GE78 HX 13VI-087IN',
#         'S3402ZA-KM501WS', 'S3402ZA-KM502WS', 'Spectre Folio',
#         'Spectre x360 13',
#         'Summit E16 Flip A13VET-068IN NVIDIA GeForce RTX 4050',
#         'Surface Laptop Go 3', 'Swift Go 14', 'TB15 G4 IAP',
#         'TN3402QA-LZ520WS', 'TN3402QA-LZ740WS', 'TUF', 'TUF GAMING F15',
#         'TUF Gaming F15', 'Thin GF63 12UC-846IN', 'Thin GF63 12VE-070IN',
#         'Thin GF63 12VE-664IN', 'Thin GF63 12VF-268IN',
#         'Thin GF63 12VF-663IN', 'ThinkBook 15 Gen 2', 'ThinkPad T14',
#         'Titan GT77HX 13VH-093IN', 'UM3402YA-KM541WS', 'UM5401QA-KM541WS',
#         'UP5401ZA-KU541WS', 'UX3402VA-KM742WS', 'V14', 'V15 G2 ALC',
#         'V15 G3 IAP', 'V15 G4', 'VICTUS 15-fb1002AX', 'VOSTRO', 'Victus',
#         'Victus 16', 'VivoBook 14', 'VivoBook 15', 'VivoBook Ultra K15',
#         'Vivobook', 'Vivobook 15', 'Vivobook 15 X1504ZA', 'Vivobook 15X',
#         'Vivobook 16X', 'Vivobook 16X\tK3605VU', 'Vivobook 17',
#         'Vivobook Go 14', 'Vivobook Go 15 OLED', 'Vivobook Pro 15 Creator',
#         'Vivobook S 14 Flip', 'Vivobook S15 OLED', 'Vivobook-Pro-15-M6500',
#         'Vostro', 'Vostro 3400', 'Vostro 3420', 'Vostro 3425',
#         'Vostro 3525', 'Vostro 5620', 'WL-Nuvobook S1-SLV',
#         'WL-Nuvobook S2-SLV', 'WL-Nuvobook V1-BLU', 'WL-Nuvobook V1-GRN',
#         'X1404VA-NK542WS', 'X1500EA', 'X1500EA-EJ311W', 'X1502ZA-EJ331WS',
#         'X1502ZA-EJ515WS', 'X1502ZA-EJ953WS', 'X1504ZA-NJ521WS',
#         'X1605VAB-MB544WS', 'X415EA-EK326WS', 'X415EA-EK344WS',
#         'X415KA-EK111WS', 'X515EA-EJ312W', 'X515EA-EJ342WS',
#         'X515EA-EJ522WS', 'X515EA-EJ701WS', 'X515EA-EZ311WS',
#         'X515JA-BQ322WS', 'XD0007ax', 'XL21', 'XL25', 'XL28', 'XL30',
#         'XL422', 'XPS 13', 'ZEB-NBC 2S', 'ZEB-NBC 3S', 'ZEB-NBC 5S',
#         'ZL513', 'Zenbook 14 Flip OLED', 'e0333ax', 'ef2033TU',
#         'ideapad 3', 's14', 'x360-bf0063TU'], dtype=object)]

# %%
column_trans = make_column_transformer((OneHotEncoder(categories=ohe.categories_),['Brand','Model Name']),remainder='passthrough')

# %% [markdown]
# # Apply LinearRegression Model

# %%
from sklearn.linear_model import LinearRegression
from sklearn.pipeline import make_pipeline
from sklearn.metrics import r2_score

# %%
lr = LinearRegression()

# %%
pipe = make_pipeline(column_trans,lr)

# %%
pipe.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('onehotencoder',
#                                                   OneHotEncoder(categories=[array(['ASUS', 'Acer', 'Apple', 'CHUWI', 'DELL', 'GIGABYTE', 'HP',
#        'Infinix', 'LG', 'Lenovo', 'MICROSOFT', 'MSI', 'Primebook',
#        'SAMSUNG', 'Ultimus', 'WINGS', 'ZEBRONICS', 'realme'], dtype=object),
#                                                                             array(['11IGL05', '13-BE0030AU', '13AB...
#        'X415KA-EK111WS', 'X515EA-EJ312W', 'X515EA-EJ342WS',
#        'X515EA-EJ522WS', 'X515EA-EJ701WS', 'X515EA-EZ311WS',
#        'X515JA-BQ322WS', 'XD0007ax', 'XL21', 'XL25', 'XL28', 'XL30',
#        'XL422', 'XPS 13', 'ZEB-NBC 2S', 'ZEB-NBC 3S', 'ZEB-NBC 5S',
#        'ZL513', 'Zenbook 14 Flip OLED', 'e0333ax', 'ef2033TU',
#        'ideapad 3', 's14', 'x360-bf0063TU'], dtype=object)]),
#                                                   ['Brand', 'Model Name'])])),
#                 ('linearregression', LinearRegression())])

# %%
y_pred = pipe.predict(X_test)

# %%
print('R2_Score for LinearRegression: ',r2_score(y_test,y_pred))
# Out:
# R2_Score for LinearRegression:  0.530106489136756

# %% [markdown]
# # Real Data Prediction for LinearRegression

# %%
pipe.predict(pd.DataFrame([['HP','15s-fq5007TU',512,8,39.62,0,0,1,0,0,0,0,0,1]],columns=['Brand','Model Name','Storage(GB)','RAM(GB)','Screen Size(CM)','Touch Screen','Processor_Amd','Processor_Intel','Processor_Mac','Processor_Others','Operating System_Chrome OS','Operating System_Mac OS','Operating System_Others','Operating System_Windows OS']))
# Out:
# array([[38998.12773948]])

# %%
pipe.predict(pd.DataFrame([['Apple','XL25',256,16,15.56,1,0,0,1,0,0,1,0,0]],columns=['Brand','Model Name','Storage(GB)','RAM(GB)','Screen Size(CM)','Touch Screen','Processor_Amd','Processor_Intel','Processor_Mac','Processor_Others','Operating System_Chrome OS','Operating System_Mac OS','Operating System_Others','Operating System_Windows OS']))
# Out:
# array([[174802.43401706]])

# %% [markdown]
# # Apply Lasso Model

# %%
from sklearn.linear_model import Lasso

# %%
ls = Lasso()

# %%
pipe = make_pipeline(column_trans,ls)

# %%
pipe.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('onehotencoder',
#                                                   OneHotEncoder(categories=[array(['ASUS', 'Acer', 'Apple', 'CHUWI', 'DELL', 'GIGABYTE', 'HP',
#        'Infinix', 'LG', 'Lenovo', 'MICROSOFT', 'MSI', 'Primebook',
#        'SAMSUNG', 'Ultimus', 'WINGS', 'ZEBRONICS', 'realme'], dtype=object),
#                                                                             array(['11IGL05', '13-BE0030AU', '13AB...
#        'X415KA-EK111WS', 'X515EA-EJ312W', 'X515EA-EJ342WS',
#        'X515EA-EJ522WS', 'X515EA-EJ701WS', 'X515EA-EZ311WS',
#        'X515JA-BQ322WS', 'XD0007ax', 'XL21', 'XL25', 'XL28', 'XL30',
#        'XL422', 'XPS 13', 'ZEB-NBC 2S', 'ZEB-NBC 3S', 'ZEB-NBC 5S',
#        'ZL513', 'Zenbook 14 Flip OLED', 'e0333ax', 'ef2033TU',
#        'ideapad 3', 's14', 'x360-bf0063TU'], dtype=object)]),
#                                                   ['Brand', 'Model Name'])])),
#                 ('lasso', Lasso())])

# %%
y_pred = pipe.predict(X_test)

# %%
print('R2_Score for Lasso: ',r2_score(y_test,y_pred))
# Out:
# R2_Score for Lasso:  0.615635562318159

# %% [markdown]
# # Real Data Prediction for Lasso

# %%
pipe.predict(pd.DataFrame([['HP','15s-fq5007TU',512,8,39.62,0,0,1,0,0,0,0,0,1]],columns=['Brand','Model Name','Storage(GB)','RAM(GB)','Screen Size(CM)','Touch Screen','Processor_Amd','Processor_Intel','Processor_Mac','Processor_Others','Operating System_Chrome OS','Operating System_Mac OS','Operating System_Others','Operating System_Windows OS']))
# Out:
# array([39013.06453502])

# %%
pipe.predict(pd.DataFrame([['Apple','XL25',256,16,15.56,1,0,0,1,0,0,1,0,0]],columns=['Brand','Model Name','Storage(GB)','RAM(GB)','Screen Size(CM)','Touch Screen','Processor_Amd','Processor_Intel','Processor_Mac','Processor_Others','Operating System_Chrome OS','Operating System_Mac OS','Operating System_Others','Operating System_Windows OS']))
# Out:
# array([171525.03727064])
